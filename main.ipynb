# %%
import matplotlib.pyplot as plt
import random

# Nombre de villes
num_villes = 10

# Générer des coordonnées aléatoires pour les villes
villes = [(random.uniform(0, 100), random.uniform(0, 100)) for _ in range(num_villes)]

# Créer une figure pour afficher la carte
plt.figure(figsize=(8, 6))

# Tracer les villes sur la carte
for i, (x, y) in enumerate(villes):
    plt.scatter(x, y, c='b', marker='o')
    plt.text(x, y, f'Ville {i}', fontsize=12, ha='left')

# Afficher la carte
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Carte Routière Fictive')
plt.grid()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

# Créez un graphe non orienté
G = nx.Graph()

# Nombre de sommets (emplacements sur la carte)
num_sommets = 50

# Ajoutez les sommets au graphe
for i in range(num_sommets):
    G.add_node(i, pos=(random.uniform(0, 100), random.uniform(0, 100)))  # Coordonnées aléatoires pour chaque sommet

# Ajoutez des arêtes pondérées (temps moyen pour parcourir)
for i in range(num_sommets):
    for j in range(i + 1, num_sommets):
        distance = random.uniform(1, 10)  # Temps moyen de parcours aléatoire (1-10 unités)
        G.add_edge(i, j, weight=distance)

# Dessinez le graphe
pos = nx.get_node_attributes(G, 'pos')
edges, weights = zip(*nx.get_edge_attributes(G, 'weight').items())

plt.figure(figsize=(10, 8))
nx.draw(G, pos, node_size=10, node_color='b', edgelist=edges, edge_color=weights, width=0.5, cmap=plt.cm.Blues)
plt.title("Carte Routière Fictive")
plt.colorbar(label="Temps moyen de parcours")
plt.axis('off')
plt.show()
# Out:
# C:\Users\Florent\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\networkx\drawing\nx_pylab.py:433: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 28
#      26 nx.draw(G, pos, node_size=10, node_color='b', edgelist=edges, edge_color=weights, width=0.5, cmap=plt.cm.Blues)
#      27 plt.title("Carte Routière Fictive")
# ---> 28 plt.colorbar(label="Temps moyen de parcours")
#      29 plt.axis('off')
#      30 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\pyplot.py:2133, in colorbar(mappable, cax, ax, **kwargs)
#    2131     mappable = gci()
#    2132     if mappable is None:
# -> 2133         raise RuntimeError('No mappable was found to use for colorbar '
#    2134                            'creation. First define a mappable such as '
#    2135                            'an image (with imshow) or a contour set ('
#    2136                            'with contourf).')
#    2137 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2138 return ret
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).

# %%
print ("hello world")
# Out:
# hello world

# %%
import folium

# Créer une carte centrée sur une position géographique (latitude, longitude)
m = folium.Map(location=[43.7102, 7.2620], zoom_start=12)  # Par exemple, Nice, France

# Ajouter des marqueurs pour le point de départ et d'arrivée
start_location = [43.7102, 7.2620]
end_location = [43.6047, 7.1977]  # Par exemple, Cannes, France
folium.Marker(start_location, tooltip='Point de départ').add_to(m)
folium.Marker(end_location, tooltip='Point d\'arrivée').add_to(m)

# Ajouter une ligne reliant les deux points
folium.PolyLine([start_location, end_location], color="blue").add_to(m)

# Afficher la carte
m.save('itineraire.html')  # Sauvegarder la carte au format HTML
